# %% [markdown]
# __DATA CLEANING__

# %%
import re
import html
from bs4 import BeautifulSoup
import pandas as pd

# %%
df = pd.read_csv("../data/paycell_reviews_play_store.csv")
df
# Out:
#                                                    Yorum  Puan  \
# 0      şuan uygulama da sorunlar var bankadan karta p...     1
# 1      bir türlü decont alamıyoruz. bazı yerler ödeme...     1
# 2      bu nasıl bir uygulama bir haftadır açmaya çalı...     1
# 3             yabancı olduğum için doğrulama yapamıyorum     1
# 4      şifre güncelle diyorsunuz ama guncelletmiuorsu...     3
# ...                                                  ...   ...
# 68634                                          Çok güzel     5
# 68635  Mobil ödeme bakiye ve islem tarihcesi goruntul...     5
# 68636                                       Beklemedeyiz     4
# 68637                                        Fine hit :)     5
# 68638                 Gayet başarılı ve kullanıcı dostu.     5
#
#                      Tarih
# 0      2025-07-07 10:25:20
# 1      2025-07-07 09:08:45
# 2      2025-07-06 22:22:35
# 3      2025-07-06 20:02:06
# 4      2025-07-06 18:34:42
# ...                    ...
# ...

# %%
def clean_text(text):
    if pd.isnull(text):
        return ""

    # for html
    text = BeautifulSoup(text, 'html.parser').get_text()
    text = html.unescape(text)

    text = re.sub(r'http\S+|www.\S+', '', text) 
    text = re.sub(r'[^\w\sçğıöşüÇĞİÖŞÜ]', '', text, flags=re.UNICODE)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = text.lower()
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# %%
df['Temiz_Yorum'] = df['Yorum'].apply(clean_text)
df[['Yorum', 'Temiz_Yorum']]
# Out:
#                                                    Yorum  \
# 0      şuan uygulama da sorunlar var bankadan karta p...
# 1      bir türlü decont alamıyoruz. bazı yerler ödeme...
# 2      bu nasıl bir uygulama bir haftadır açmaya çalı...
# 3             yabancı olduğum için doğrulama yapamıyorum
# 4      şifre güncelle diyorsunuz ama guncelletmiuorsu...
# ...                                                  ...
# 68634                                          Çok güzel
# 68635  Mobil ödeme bakiye ve islem tarihcesi goruntul...
# 68636                                       Beklemedeyiz
# 68637                                        Fine hit :)
# 68638                 Gayet başarılı ve kullanıcı dostu.
#
#                                              Temiz_Yorum
# 0      şuan uygulama da sorunlar var bankadan karta p...
# 1      bir türlü decont alamıyoruz bazı yerler ödeme ...
# 2      bu nasıl bir uygulama bir haftadır açmaya çalı...
# ...

# %% [markdown]
# __PREPROCESSING__

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import string

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\ismet
# [nltk_data]     bal\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\ismet
# [nltk_data]     bal\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words("turkish"))

def tokenize_and_remove_stopwords(text):
    tokens = word_tokenize(text, language='turkish')
    filtered_tokens = [word for word in tokens if word.lower() not in stop_words and word not in string.punctuation]
    return filtered_tokens
    
df["tokens"] = df["Temiz_Yorum"].apply(tokenize_and_remove_stopwords)
df[["Yorum", "Temiz_Yorum", "tokens"]].head()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[22], line 8
#       5     filtered_tokens = [word for word in tokens if word.lower() not in stop_words and word not in string.punctuation]
#       6     return filtered_tokens
# ----> 8 df["tokens"] = df["Temiz_Yorum"].apply(tokenize_and_remove_stopwords)
#       9 df[["Yorum", "Temiz_Yorum", "tokens"]].head()
#
# File ~\anaconda3\envs\paycell_review_analysis\lib\site-packages\pandas\core\series.py:4935, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4800 def apply(
#    4801     self,
#    4802     func: AggFuncType,
#    (...)
#    4807     **kwargs,
#    4808 ) -> DataFrame | Series:
#    4809     """
#    4810     Invoke function on values of Series.
#    4811
#    (...)
#    4926     dtype: float64
#    4927     """
#    4928     return SeriesApply(
#    4929         self,
# ...
