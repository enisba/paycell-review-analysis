# %% [markdown]
# # DATA CLEANING

# %%
import re
import html
from bs4 import BeautifulSoup
import pandas as pd

# %%
df = pd.read_csv("../data/paycell_reviews_play_store.csv")
df
# Out:
#                                                    Yorum  Puan  \
# 0                                         sakin girmeyin     1
# 1      Uygulamada arkadaşını davet et butonu çalışmıy...     4
# 2                                      SMS KODU GELMİYOR     1
# 3      geçici olarak IBAN bilgilerine ulaşılamıyor di...     5
# 4      onaylayabilmek için telefonumun NFC özelliğini...     1
# ...                                                  ...   ...
# 68634  Uygulama Çok İyi Ancak Günlük Giriş Olarak Kre...     5
# 68635  Arkadaş turk sel bayi email adresimi yanlış gi...     1
# 68636  Arena of valor oyununa 3,89 nakit cektim oyuna...     3
# 68637                          Arayuz gercekten cok iyi.     5
# 68638  Annesizler bizi ne dolandiriyosunuz polise ver...     1
#
#                      Tarih
# 0      2025-07-19 22:54:03
# 1      2025-07-19 15:19:42
# 2      2025-07-19 09:00:43
# 3      2025-07-19 06:27:28
# 4      2025-07-18 14:50:20
# ...                    ...
# 68634  2017-10-25 19:51:01
# 68635  2017-10-25 15:07:58
# 68636  2017-10-21 10:55:40
# 68637  2017-10-18 19:05:47
# 68638  2017-10-18 19:03:53
#
# [68639 rows x 3 columns]

# %%
def clean_text(text):
    if pd.isnull(text):
        return ""

    # html cleaning
    text = BeautifulSoup(text, 'html.parser').get_text()
    text = html.unescape(text)

    # clasic cleaning
    text = re.sub(r'http\S+|www.\S+', '', text)
    text = re.sub(r'[^\w\sçğıöşüÇĞİÖŞÜ]', '', text, flags=re.UNICODE)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = text.lower()
    text = re.sub(r'\s+', ' ', text).strip()
    
     # emoji cleaning
    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"
        "\U0001F300-\U0001F5FF"
        "\U0001F680-\U0001F6FF"
        "\U0001F1E0-\U0001F1FF"
        "\U00002700-\U000027BF"
        "\U0001F900-\U0001F9FF"
        "\U00002600-\U000026FF"
        "]+",
        flags=re.UNICODE
    )
    text = emoji_pattern.sub(r'', text)

    return text

# %%
df['Temiz_Yorum'] = df['Yorum'].apply(clean_text)
df[['Yorum', 'Temiz_Yorum']]
# Out:
#                                                    Yorum  \
# 0                                         sakin girmeyin
# 1      Uygulamada arkadaşını davet et butonu çalışmıy...
# 2                                      SMS KODU GELMİYOR
# 3      geçici olarak IBAN bilgilerine ulaşılamıyor di...
# 4      onaylayabilmek için telefonumun NFC özelliğini...
# ...                                                  ...
# 68634  Uygulama Çok İyi Ancak Günlük Giriş Olarak Kre...
# 68635  Arkadaş turk sel bayi email adresimi yanlış gi...
# 68636  Arena of valor oyununa 3,89 nakit cektim oyuna...
# 68637                          Arayuz gercekten cok iyi.
# 68638  Annesizler bizi ne dolandiriyosunuz polise ver...
#
#                                              Temiz_Yorum
# 0                                         sakin girmeyin
# 1      uygulamada arkadaşını davet et butonu çalışmıy...
# 2                                     sms kodu gelmi̇yor
# 3      geçici olarak iban bilgilerine ulaşılamıyor di...
# 4      onaylayabilmek için telefonumun nfc özelliğini...
# ...                                                  ...
# 68634  uygulama çok i̇yi ancak günlük giriş olarak kr...
# 68635  arkadaş turk sel bayi email adresimi yanlış gi...
# 68636  arena of valor oyununa nakit cektim oyuna para...
# 68637                           arayuz gercekten cok iyi
# 68638  annesizler bizi ne dolandiriyosunuz polise ver...
#
# [68639 rows x 2 columns]

# %% [markdown]
# __Spelling error detection was performed using the Zemberek NLP library, and the data cleaning process is currently in progress.__

# %%
from jpype import startJVM, getDefaultJVMPath, JClass, isJVMStarted

ZEMBEREK_PATH = "zemberek-full.jar"

if not isJVMStarted():
    startJVM(getDefaultJVMPath(), "-ea", f"-Djava.class.path={ZEMBEREK_PATH}")

# %%
TurkishSpellChecker = JClass("zemberek.normalization.TurkishSpellChecker")
TurkishMorphology = JClass("zemberek.morphology.TurkishMorphology")
morphology = TurkishMorphology.createWithDefaults()
spell_checker = TurkishSpellChecker(morphology)

# %%
def correct_spelling(text):
    words = text.split()
    corrected_words = []
    for word in words:
        if spell_checker.check(word):
            corrected_words.append(str(word))  
        else:
            suggestions = spell_checker.suggestForWord(word)
            if not suggestions.isEmpty():
                corrected_words.append(str(suggestions.get(0))) 
            else:
                corrected_words.append(str(word))
    return " ".join(corrected_words)

# %%
df["yazim_hatasiz"] = df["Temiz_Yorum"].astype(str).apply(correct_spelling)
df[["Yorum", "yazim_hatasiz"]]
# Out:
#                                                    Yorum  \
# 0                                         sakin girmeyin
# 1      Uygulamada arkadaşını davet et butonu çalışmıy...
# 2                                      SMS KODU GELMİYOR
# 3      geçici olarak IBAN bilgilerine ulaşılamıyor di...
# 4      onaylayabilmek için telefonumun NFC özelliğini...
# ...                                                  ...
# 68634  Uygulama Çok İyi Ancak Günlük Giriş Olarak Kre...
# 68635  Arkadaş turk sel bayi email adresimi yanlış gi...
# 68636  Arena of valor oyununa 3,89 nakit cektim oyuna...
# 68637                          Arayuz gercekten cok iyi.
# 68638  Annesizler bizi ne dolandiriyosunuz polise ver...
#
#                                            yazim_hatasiz
# 0                                         sakin girmeyin
# 1      uygulamada arkadaşını davet et butonu çalışmıy...
# 2                                      ses kodu gelmiyor
# 3      geçici olarak ilan bilgilerine ulaşılamıyor di...
# 4      onaylayabilmek için telefonumun nbc özelliğini...
# ...                                                  ...
# 68634  uygulama çok iyi ancak günlük giriş olarak kre...
# 68635  arkadaş Türk sel bayi mail adresimi yanlış gir...
# 68636  arena of Valon oyununa nakit çektim oyuna para...
# 68637                           arayüz gerçekten çok iyi
# 68638  annesizler bizi ne dolandiriyosunuz polise ver...
#
# [68639 rows x 2 columns]

# %% [markdown]
# # PREPROCESSING

# %% [markdown]
# STOPWORDS
# and TOKENAZATION

# %% [markdown]
# __Stopword removal was performed using a predefined list of Turkish stopwords.__

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import string

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\ismet
# [nltk_data]     bal\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words("turkish"))

def remove_stopwords(text):
    tokens = text.split() 
    filtered_tokens = [word.lower() for word in tokens 
                       if word.lower() not in stop_words and
                       word not in string.punctuation and
                       len(word) > 2]
    return filtered_tokens

df = df[df["yazim_hatasiz"].notnull()]
df["tokens"] = df["yazim_hatasiz"].astype(str).apply(remove_stopwords)
df[["Yorum", "yazim_hatasiz", "tokens"]]
# Out:
#                                                    Yorum  \
# 0                                         sakin girmeyin
# 1      Uygulamada arkadaşını davet et butonu çalışmıy...
# 2                                      SMS KODU GELMİYOR
# 3      geçici olarak IBAN bilgilerine ulaşılamıyor di...
# 4      onaylayabilmek için telefonumun NFC özelliğini...
# ...                                                  ...
# 68634  Uygulama Çok İyi Ancak Günlük Giriş Olarak Kre...
# 68635  Arkadaş turk sel bayi email adresimi yanlış gi...
# 68636  Arena of valor oyununa 3,89 nakit cektim oyuna...
# 68637                          Arayuz gercekten cok iyi.
# 68638  Annesizler bizi ne dolandiriyosunuz polise ver...
#
#                                            yazim_hatasiz  \
# 0                                         sakin girmeyin
# 1      uygulamada arkadaşını davet et butonu çalışmıy...
# 2                                      ses kodu gelmiyor
# 3      geçici olarak ilan bilgilerine ulaşılamıyor di...
# 4      onaylayabilmek için telefonumun nbc özelliğini...
# ...                                                  ...
# 68634  uygulama çok iyi ancak günlük giriş olarak kre...
# 68635  arkadaş Türk sel bayi mail adresimi yanlış gir...
# 68636  arena of Valon oyununa nakit çektim oyuna para...
# 68637                           arayüz gerçekten çok iyi
# 68638  annesizler bizi ne dolandiriyosunuz polise ver...
#
#                                                   tokens
# 0                                      [sakin, girmeyin]
# 1      [uygulamada, arkadaşını, davet, butonu, çalışm...
# 2                                  [ses, kodu, gelmiyor]
# 3      [geçici, olarak, ilan, bilgilerine, ulaşılamıy...
# 4      [onaylayabilmek, telefonumun, nbc, özelliğinin...
# ...                                                  ...
# 68634  [uygulama, iyi, ancak, günlük, giriş, olarak, ...
# 68635  [arkadaş, türk, sel, bayi, mail, adresimi, yan...
# 68636  [arena, valon, oyununa, nakit, çektim, oyuna, ...
# 68637                           [arayüz, gerçekten, iyi]
# 68638  [annesizler, bizi, dolandiriyosunuz, polise, v...
#
# [68639 rows x 3 columns]

# %% [markdown]
# __ZEMBEREK USING STEMMING AND LEMMAZATION__

# %% [markdown]
# __Zemberek was used to extract the root forms (lemmas) of the words.__

# %%
def lemmatizeTokens(tokens, morphology):
    lemmas = []
    for tok in tokens:
        analyses = morphology.analyzeAndDisambiguate(tok).bestAnalysis()
        if analyses.size() > 0:
            lemma = str(analyses.get(0).getLemmas()[0])
            lemmas.append(lemma if lemma != 'UNK' else tok)
        else:
            lemmas.append(tok)
    return lemmas

df["lemmas"] = df["tokens"].apply(lambda x: lemmatizeTokens(x, morphology))

# %%
df[["Yorum", "tokens", "lemmas"]]
# Out:
#                                                    Yorum  \
# 0                                         sakin girmeyin
# 1      Uygulamada arkadaşını davet et butonu çalışmıy...
# 2                                      SMS KODU GELMİYOR
# 3      geçici olarak IBAN bilgilerine ulaşılamıyor di...
# 4      onaylayabilmek için telefonumun NFC özelliğini...
# ...                                                  ...
# 68634  Uygulama Çok İyi Ancak Günlük Giriş Olarak Kre...
# 68635  Arkadaş turk sel bayi email adresimi yanlış gi...
# 68636  Arena of valor oyununa 3,89 nakit cektim oyuna...
# 68637                          Arayuz gercekten cok iyi.
# 68638  Annesizler bizi ne dolandiriyosunuz polise ver...
#
#                                                   tokens  \
# 0                                      [sakin, girmeyin]
# 1      [uygulamada, arkadaşını, davet, butonu, çalışm...
# 2                                  [ses, kodu, gelmiyor]
# 3      [geçici, olarak, ilan, bilgilerine, ulaşılamıy...
# 4      [onaylayabilmek, telefonumun, nbc, özelliğinin...
# ...                                                  ...
# 68634  [uygulama, iyi, ancak, günlük, giriş, olarak, ...
# 68635  [arkadaş, türk, sel, bayi, mail, adresimi, yan...
# 68636  [arena, valon, oyununa, nakit, çektim, oyuna, ...
# 68637                           [arayüz, gerçekten, iyi]
# 68638  [annesizler, bizi, dolandiriyosunuz, polise, v...
#
#                                                   lemmas
# 0                                           [sakin, gir]
# 1      [uygula, arkadaş, davet, buton, çalış, program...
# 2                                        [ses, kod, gel]
# 3        [geçici, ol, ilan, bilgi, ulaş, de, sorun, çöz]
# 4      [onayla, telefon, nbc, özellik, ol, zorunlu, s...
# ...                                                  ...
# 68634  [uygula, iyi, ancak, günlük, giriş, ol, kredi,...
# 68635  [arkadaş, türk, sel, bayi, mail, adres, yanlış...
# 68636  [arena, valon, oyun, nakit, çek, oyun, para, g...
# 68637                           [arayüz, gerçekten, iyi]
# 68638  [anne, biz, dolandiriyosunuz, polis, ver, siz,...
#
# [68639 rows x 3 columns]

# %%
df = df[df["lemmas"].apply(lambda x: len(x) > 0)]

# %% [markdown]
# __High-frequency and non-informative words were eliminated to obtain a more meaningful dataset.__

# %%
remove_words = set(["uygula", "yap", "et", "ver", "al", "bir", "ol", "de", "ben", "gel"])

def clean_lemmas(val):
    try:
        if isinstance(val, str):
            val = ast.literal_eval(val)
        return [w for w in val if w.lower() not in remove_words]
    except Exception as e:
        print(f"Hata: {e} → {val}")
        return []

df["lemmas"] = df["lemmas"].apply(clean_lemmas)

# %%
def clean_lemmas(lemmas):
    return [w for w in lemmas if len(w) > 2]

df["lemmas"] = df["lemmas"].apply(clean_lemmas)

df = df[df["lemmas"].apply(lambda x: len(x) > 0)]

# %% [markdown]
# __These examples demonstrate the effect of preprocessing steps on the dataset.__

# %%
df.head()
# Out:
#                                                Yorum  Puan  \
# 0                                     sakin girmeyin     1
# 1  Uygulamada arkadaşını davet et butonu çalışmıy...     4
# 2                                  SMS KODU GELMİYOR     1
# 3  geçici olarak IBAN bilgilerine ulaşılamıyor di...     5
# 4  onaylayabilmek için telefonumun NFC özelliğini...     1
#
#                  Tarih                                        Temiz_Yorum  \
# 0  2025-07-19 22:54:03                                     sakin girmeyin
# 1  2025-07-19 15:19:42  uygulamada arkadaşını davet et butonu çalışmıy...
# 2  2025-07-19 09:00:43                                 sms kodu gelmi̇yor
# 3  2025-07-19 06:27:28  geçici olarak iban bilgilerine ulaşılamıyor di...
# 4  2025-07-18 14:50:20  onaylayabilmek için telefonumun nfc özelliğini...
#
#                                        yazim_hatasiz  \
# 0                                     sakin girmeyin
# 1  uygulamada arkadaşını davet et butonu çalışmıy...
# 2                                  ses kodu gelmiyor
# 3  geçici olarak ilan bilgilerine ulaşılamıyor di...
# 4  onaylayabilmek için telefonumun nbc özelliğini...
#
#                                               tokens  \
# 0                                  [sakin, girmeyin]
# 1  [uygulamada, arkadaşını, davet, butonu, çalışm...
# 2                              [ses, kodu, gelmiyor]
# 3  [geçici, olarak, ilan, bilgilerine, ulaşılamıy...
# 4  [onaylayabilmek, telefonumun, nbc, özelliğinin...
#
#                                               lemmas
# 0                                       [sakin, gir]
# 1   [arkadaş, davet, buton, çalış, program, kilitle]
# 2                                         [ses, kod]
# 3            [geçici, ilan, bilgi, ulaş, sorun, çöz]
# 4  [onayla, telefon, nbc, özellik, zorunlu, saçma...

# %%
df[["lemmas", "Puan", "Tarih"]].to_csv("../data/preprocessed_review.csv", index = False)

# %% [markdown]
# __Some visualizations were created to better understand the data. The results are shown below.__

# %%
df = pd.read_csv("../data/preprocessed_review.csv")

# %%
df.head()
# Out:
#                                               lemmas  Puan  \
# 0                                   ['sakin', 'gir']     1
# 1  ['arkadaş', 'davet', 'buton', 'çalış', 'progra...     4
# 2                                     ['ses', 'kod']     1
# 3  ['geçici', 'ilan', 'bilgi', 'ulaş', 'sorun', '...     5
# 4  ['onayla', 'telefon', 'nbc', 'özellik', 'zorun...     1
#
#                  Tarih
# 0  2025-07-19 22:54:03
# 1  2025-07-19 15:19:42
# 2  2025-07-19 09:00:43
# 3  2025-07-19 06:27:28
# 4  2025-07-18 14:50:20

# %%
df['review_length'] = df['lemmas'].apply(lambda x: len(str(x).split()))
df['review_length'].describe()
# Out:
# count    65964.000000
# mean         5.588594
# std          8.105329
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          7.000000
# max        103.000000
# Name: review_length, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
counts, bins, patches = plt.hist(df['review_length'], bins=50, color='skyblue', edgecolor='black')

for count, bin_left, bin_right in zip(counts, bins[:-1], bins[1:]):
    bin_center = (bin_left + bin_right) / 2
    if count > 0:
        plt.text(bin_center, count + 1, str(int(count)), ha='center', va='bottom', fontsize=8)

plt.title("Yorum Uzunluk Dağılımı")
plt.xlabel("Kelime Sayısı")
plt.ylabel("Yorum Sayısı")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import ast

df['lemmas'] = df['lemmas'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

all_words = [word for tokens in df['lemmas'] for word in tokens]
text = " ".join(all_words)

from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(15, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("En Sık Geçen Kelimeler")
plt.show()

# %%
from collections import Counter

all_words = [word for tokens in df["lemmas"] for word in tokens if word.lower() not in stop_words]
word_freq = Counter(all_words).most_common(20)

words, freqs = zip(*word_freq)

plt.figure(figsize=(10,5))
bars = plt.bar(words, freqs, color='skyblue', edgecolor='black')
plt.xticks(rotation=45)
plt.title("En Sık Geçen 20 Kelime")
plt.ylabel("Frekans")

for bar, freq in zip(bars, freqs):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 1, str(freq),
             ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# __With preprocessing finished, the dataset is now clean and ready for the next steps.__
