# %% [markdown]
# __DATA CLEANING__

# %%
import re
import html
from bs4 import BeautifulSoup
import pandas as pd

# %%
df = pd.read_csv("../data/paycell_reviews_play_store.csv")
df
# Out:
#                                                    Yorum  Puan  \
# 0      şuan uygulama da sorunlar var bankadan karta p...     1
# 1      bir türlü decont alamıyoruz. bazı yerler ödeme...     1
# 2      bu nasıl bir uygulama bir haftadır açmaya çalı...     1
# 3             yabancı olduğum için doğrulama yapamıyorum     1
# 4      şifre güncelle diyorsunuz ama guncelletmiuorsu...     3
# ...                                                  ...   ...
# 68634                                          Çok güzel     5
# 68635  Mobil ödeme bakiye ve islem tarihcesi goruntul...     5
# 68636                                       Beklemedeyiz     4
# 68637                                        Fine hit :)     5
# 68638                 Gayet başarılı ve kullanıcı dostu.     5
#
#                      Tarih
# 0      2025-07-07 10:25:20
# 1      2025-07-07 09:08:45
# 2      2025-07-06 22:22:35
# 3      2025-07-06 20:02:06
# 4      2025-07-06 18:34:42
# ...                    ...
# 68634  2017-08-25 10:43:11
# 68635  2017-08-19 15:08:30
# 68636  2017-08-17 06:38:45
# 68637  2017-08-16 20:23:34
# 68638  2017-08-15 22:20:51
#
# [68639 rows x 3 columns]

# %%
def clean_text(text):
    if pd.isnull(text):
        return ""

    # for html
    text = BeautifulSoup(text, 'html.parser').get_text()
    text = html.unescape(text)

    text = re.sub(r'http\S+|www.\S+', '', text) 
    text = re.sub(r'[^\w\sçğıöşüÇĞİÖŞÜ]', '', text, flags=re.UNICODE)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = text.lower()
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# %%
df['Temiz_Yorum'] = df['Yorum'].apply(clean_text)
df[['Yorum', 'Temiz_Yorum']]
# Out:
#                                                    Yorum  \
# 0      şuan uygulama da sorunlar var bankadan karta p...
# 1      bir türlü decont alamıyoruz. bazı yerler ödeme...
# 2      bu nasıl bir uygulama bir haftadır açmaya çalı...
# 3             yabancı olduğum için doğrulama yapamıyorum
# 4      şifre güncelle diyorsunuz ama guncelletmiuorsu...
# ...                                                  ...
# 68634                                          Çok güzel
# 68635  Mobil ödeme bakiye ve islem tarihcesi goruntul...
# 68636                                       Beklemedeyiz
# 68637                                        Fine hit :)
# 68638                 Gayet başarılı ve kullanıcı dostu.
#
#                                              Temiz_Yorum
# 0      şuan uygulama da sorunlar var bankadan karta p...
# 1      bir türlü decont alamıyoruz bazı yerler ödeme ...
# 2      bu nasıl bir uygulama bir haftadır açmaya çalı...
# 3             yabancı olduğum için doğrulama yapamıyorum
# 4      şifre güncelle diyorsunuz ama guncelletmiuorsu...
# ...                                                  ...
# 68634                                          çok güzel
# 68635  mobil ödeme bakiye ve islem tarihcesi goruntul...
# 68636                                       beklemedeyiz
# 68637                                           fine hit
# 68638                  gayet başarılı ve kullanıcı dostu
#
# [68639 rows x 2 columns]

# %% [markdown]
# __PREPROCESSING__

# %% [markdown]
# STOPWORDS AND TOKENAZATION

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import string

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\ismet
# [nltk_data]     bal\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words("turkish"))

def remove_stopwords(text):
    tokens = text.split() 
    filtered_tokens = [word.lower() for word in tokens 
                       if word.lower() not in stop_words and
                       word not in string.punctuation and
                       len(word) > 2]
    return filtered_tokens

df = df[df["Temiz_Yorum"].notnull()]
df["tokens"] = df["Temiz_Yorum"].astype(str).apply(remove_stopwords)
df[["Yorum", "Temiz_Yorum", "tokens"]]
# Out:
#                                                    Yorum  \
# 0      şuan uygulama da sorunlar var bankadan karta p...
# 1      bir türlü decont alamıyoruz. bazı yerler ödeme...
# 2      bu nasıl bir uygulama bir haftadır açmaya çalı...
# 3             yabancı olduğum için doğrulama yapamıyorum
# 4      şifre güncelle diyorsunuz ama guncelletmiuorsu...
# ...                                                  ...
# 68634                                          Çok güzel
# 68635  Mobil ödeme bakiye ve islem tarihcesi goruntul...
# 68636                                       Beklemedeyiz
# 68637                                        Fine hit :)
# 68638                 Gayet başarılı ve kullanıcı dostu.
#
#                                              Temiz_Yorum  \
# 0      şuan uygulama da sorunlar var bankadan karta p...
# 1      bir türlü decont alamıyoruz bazı yerler ödeme ...
# 2      bu nasıl bir uygulama bir haftadır açmaya çalı...
# 3             yabancı olduğum için doğrulama yapamıyorum
# 4      şifre güncelle diyorsunuz ama guncelletmiuorsu...
# ...                                                  ...
# 68634                                          çok güzel
# 68635  mobil ödeme bakiye ve islem tarihcesi goruntul...
# 68636                                       beklemedeyiz
# 68637                                           fine hit
# 68638                  gayet başarılı ve kullanıcı dostu
#
#                                                   tokens
# 0      [şuan, uygulama, sorunlar, var, bankadan, kart...
# 1      [bir, türlü, decont, alamıyoruz, yerler, ödeme...
# 2      [bir, uygulama, bir, haftadır, açmaya, çalışıy...
# 3             [yabancı, olduğum, doğrulama, yapamıyorum]
# 4      [şifre, güncelle, diyorsunuz, guncelletmiuorsu...
# ...                                                  ...
# 68634                                            [güzel]
# 68635  [mobil, ödeme, bakiye, islem, tarihcesi, gorun...
# 68636                                     [beklemedeyiz]
# 68637                                        [fine, hit]
# 68638                [gayet, başarılı, kullanıcı, dostu]
#
# [68639 rows x 3 columns]

# %%
df[["tokens", "Puan", "Tarih"]].to_csv("..cleaned_reviews.csv", index=False)

# %% [markdown]
# ZEMBEREK USING STEMMING AND LEMMAZATION

# %%
from jpype import startJVM, getDefaultJVMPath, JClass

ZEMBEREK_PATH = 'zemberek-full.jar'
startJVM(getDefaultJVMPath(), '-ea', f'-Djava.class.path={ZEMBEREK_PATH}')

TurkishMorphology = JClass('zemberek.morphology.TurkishMorphology')
morphology = TurkishMorphology.createWithDefaults()
# Out:
# ---------------------------------------------------------------------------
# JVMNotFoundException                      Traceback (most recent call last)
# Cell In[1], line 4
#       1 from jpype import startJVM, getDefaultJVMPath, JClass
#       3 ZEMBEREK_PATH = 'zemberek-full.jar'
# ----> 4 startJVM(getDefaultJVMPath(), '-ea', f'-Djava.class.path={ZEMBEREK_PATH}')
#       6 TurkishMorphology = JClass('zemberek.morphology.TurkishMorphology')
#       7 morphology = TurkishMorphology.createWithDefaults()
#
# File ~\anaconda3\envs\paycell_review_analysis\lib\site-packages\jpype\_jvmfinder.py:70, in getDefaultJVMPath()
#      68 else:
#      69     finder = LinuxJVMFinder()
# ---> 70 return finder.get_jvm_path()
#
# File ~\anaconda3\envs\paycell_review_analysis\lib\site-packages\jpype\_jvmfinder.py:204, in JVMFinder.get_jvm_path(self)
#     202 if jvm_notsupport_ext is not None:
#     203     raise jvm_notsupport_ext
# --> 204 raise JVMNotFoundException("No JVM shared library file ({0}) "
#     205                            "found. Try setting up the JAVA_HOME "
#     206                            "environment variable properly."
#     207                            .format(self._libfile))
#
# JVMNotFoundException: No JVM shared library file (jvm.dll) found. Try setting up the JAVA_HOME environment variable properly.
