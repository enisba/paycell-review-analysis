# %% [markdown]
# # Modelling

# %% [markdown]
# __Raw Data Visualization__

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/preprocessed_review.csv")

# %% [markdown]
# __Labels were created and new data was prepared for sentiment analysis.__

# %%
def label_review(rate):
    if rate >= 4: return 'positive'
    elif rate == 3: return 'neutral'
    else: return 'negative'

df['sentiment'] = df['Puan'].apply(label_review)

# %%
sentiment_counts = df['sentiment'].value_counts()
labels = sentiment_counts.index.tolist()

color_map = {
    'positive': 'green',
    'neutral': 'gray',
    'negative': 'red'
}
colors = [color_map.get(label, 'skyblue') for label in labels]

plt.figure(figsize=(6, 4))
ax = sentiment_counts.plot(kind='bar', color=colors, edgecolor='black')

plt.title('Yorumların Duygu Dağılımı')
plt.xlabel('Duygu Etiketi')
plt.ylabel('Yorum Sayısı')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)

for patch in ax.patches:
    height = patch.get_height()
    plt.text(patch.get_x() + patch.get_width()/2, height + 1, str(int(height)),
             ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# __As seen here, the number of positive and negative reviews is much lower than neutral ones.This class imbalance may result in low accuracy for the neutral class during model training.__

# %%
df["review_length"] = df["lemmas"].apply(len)
avg_lengths = df.groupby("sentiment")["review_length"].mean().reindex(["negative", "neutral", "positive"])

ax = avg_lengths.plot(kind="bar", color=["red", "gray", "green"])
plt.title("Duygu Etiketine Göre Ortalama Yorum Uzunluğu")
plt.xlabel("Duygu")
plt.ylabel("Ortalama Yorum Uzunluğu (kelime)")
plt.grid(axis='y')
for i, v in enumerate(avg_lengths):
    plt.text(i, v + 0.5, f"{v:.1f}", ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# # SENTIMENT ANALYSIS

# %% [markdown]
# __We selected 'tabularisai/multilingual-sentiment-analysis' from Hugging Face for our sentiment analysis task. Turkish specific models underperformed on our dataset due to its diversity and complexity. As a result, this multilingual model which supports 15 languages was preferred, as it provided relatively better accuracy and more stable predictions.__

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

model_name = "tabularisai/multilingual-sentiment-analysis"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

sentiment_pipe = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)
# Out:
# Device set to use cuda:0

# %%
import ast

texts = df["lemmas"].dropna().apply(lambda x: " ".join(ast.literal_eval(x))).tolist()
results = sentiment_pipe(texts, batch_size=128)

# %%
df["pred_label"] = [res["label"] for res in results]
df["pred_score"] = [res["score"] for res in results]

# %%
def normalize_label(label):
    label = label.lower()
    if "neg" in label:
        return "negative"
    elif "notr" in label or "neutral" in label:
        return "neutral"
    elif "pos" in label:
        return "positive"
    return "unknown"

df["normalized_pred_label"] = df["pred_label"].apply(normalize_label)

# %% [markdown]
# __While exploring the data, I noticed that the model missed some important positive words. As a result, I manually labeled certain words as positive.__

# %%
positive_keywords = ["süper", "harika", "mükemmel", "çok güzel", "teşekkür", "bayıldım", "efsane", "beğen", "unlosttan", "unlost" ]

def force_positive(row):
    text = " ".join(ast.literal_eval(row["lemmas"])) if isinstance(row["lemmas"], str) else " ".join(row["lemmas"])
    if any(kw in text for kw in positive_keywords) or "unlost" in text:
        return "positive"
    return row["normalized_pred_label"]

df["normalized_pred_label"] = df.apply(force_positive, axis=1)

# %% [markdown]
# __According to the results from our selected model, we achieved strong performance on both negative and positive classes. However, due to the limited amount of neutral data, the model made almost no correct predictions in that class. The overall accuracy reached 74%.__

# %%
from sklearn.metrics import classification_report
print(classification_report(df["sentiment"], df["normalized_pred_label"]))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.62      0.65     18259
#      neutral       0.07      0.24      0.10      2208
#     positive       0.90      0.81      0.86     45497
#
#     accuracy                           0.74     65964
#    macro avg       0.55      0.56      0.54     65964
# weighted avg       0.81      0.74      0.77     65964

# %%
df
# Out:
#                                                   lemmas  Puan  \
# 0                                       ['sakin', 'gir']     1
# 1      ['arkadaş', 'davet', 'buton', 'çalış', 'progra...     4
# 2                                         ['ses', 'kod']     1
# 3      ['geçici', 'ilan', 'bilgi', 'ulaş', 'sorun', '...     5
# 4      ['onayla', 'telefon', 'nbc', 'özellik', 'zorun...     1
# ...                                                  ...   ...
# 65959  ['iyi', 'ancak', 'günlük', 'giriş', 'kredi', '...     5
# 65960  ['arkadaş', 'türk', 'sel', 'bayi', 'mail', 'ad...     1
# 65961  ['arena', 'valon', 'oyun', 'nakit', 'çek', 'oy...     3
# 65962                     ['arayüz', 'gerçekten', 'iyi']     5
# 65963  ['anne', 'biz', 'dolandiriyosunuz', 'polis', '...     1
#
#                      Tarih sentiment  review_length     pred_label  \
# 0      2025-07-19 22:54:03  negative             16       Positive
# 1      2025-07-19 15:19:42  positive             60  Very Negative
# 2      2025-07-19 09:00:43  negative             14        Neutral
# 3      2025-07-19 06:27:28  positive             51       Negative
# 4      2025-07-18 14:50:20  negative            176       Negative
# ...                    ...       ...            ...            ...
# 65959  2017-10-25 19:51:01  positive             51        Neutral
# 65960  2017-10-25 15:07:58  negative             84  Very Positive
# 65961  2017-10-21 10:55:40   neutral             68        Neutral
# 65962  2017-10-18 19:05:47  positive             30       Positive
# 65963  2017-10-18 19:03:53  negative             67  Very Negative
#
#        pred_score normalized_pred_label
# 0        0.357571              positive
# 1        0.275996              negative
# 2        0.321734               neutral
# 3        0.350649              negative
# 4        0.402275              negative
# ...           ...                   ...
# 65959    0.709147               neutral
# 65960    0.352934              positive
# 65961    0.301251               neutral
# 65962    0.524642              positive
# 65963    0.374175              negative
#
# [65964 rows x 8 columns]

# %%
df[["sentiment","normalized_pred_label"]]
# Out:
#       sentiment normalized_pred_label
# 0      negative              positive
# 1      positive              negative
# 2      negative               neutral
# 3      positive              negative
# 4      negative              negative
# ...         ...                   ...
# 65959  positive               neutral
# 65960  negative              positive
# 65961   neutral               neutral
# 65962  positive              positive
# 65963  negative              negative
#
# [65964 rows x 2 columns]

# %% [markdown]
# __All newly generated columns and features from the 'data' folder were examined as part of the feature engineering process.__

# %%
df[["lemmas", "sentiment", "Puan", "review_length", "normalized_pred_label", "Tarih"]].to_csv("../data/sentiment_results.csv", index=False)

# %% [markdown]
# __To improve readability, the 'sentiment' and 'pred_sentiment' columns were color-coded for better visual clarity. The corresponding file can be accessed from the 'data' folder.__

# %%
from openpyxl import load_workbook
from openpyxl.styles import PatternFill

df[["lemmas", "sentiment", "normalized_pred_label", "Tarih"]].to_excel("../data/sentiment_results.xlsx", index=False)

wb = load_workbook("../data/sentiment_results.xlsx")
ws = wb.active

colors = {"neutral": "D9D9D9", "positive": "C6EFCE", "negative": "F2DCDB"}

for row in range(2, ws.max_row + 1):
    sentiment = ws[f"B{row}"].value 
    pred = ws[f"C{row}"].value      
    if sentiment in colors:
        fill_true = PatternFill(start_color=colors[sentiment], end_color=colors[sentiment], fill_type="solid")
        ws[f"B{row}"].fill = fill_true
    if pred in colors:
        fill_pred = PatternFill(start_color=colors[pred], end_color=colors[pred], fill_type="solid")
        ws[f"C{row}"].fill = fill_pred

wb.save("../data/sentiment_results_colored.xlsx")

# %% [markdown]
# __Analysis of suggestions found in negative feedback__

# %% [markdown]
# __Negative reviews were selected and filtered using specific keywords to detect segments that include user suggestions and complaints. The extracted parts were grouped into clusters for further analysis.__

# %%
df_cleaned = pd.read_csv("../data/sentiment_results.csv")

# %%
import ast

df_cleaned["lemmas"] = df_cleaned["lemmas"].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
negatif_df = df_cleaned[df_cleaned["normalized_pred_label"] == "negative"].copy()
df_cleaned = negatif_df.dropna(subset=["lemmas"])

# %% [markdown]
# __At this step, keywords indicating suggestions were defined and selected.__

# %%
suggest_df = df_cleaned[
    df_cleaned["lemmas"].apply(lambda x: any(
        word in x for word in [
    "bence", "keşke", "ol", "geliştir", "ek", "daha", "iyi", "eksik", "şöyle",
    "böyle", "öner", "düzenle", "gerek", "ist", "lazım", "koy", "çıkar", "yenile",
    "artır", "azalt", "sağla", "sun", "yap", "olabilir", "olsun"        ]
    ))
]

# %% [markdown]
# __Using the KeyBERT model with 'paraphrase-multilingual-MiniLM-L12-v2', semantic relations between words were extracted. As a result, suggestion clusters and common themes were identified.__

# %%
from keybert import KeyBERT

kw_model = KeyBERT(model="paraphrase-multilingual-MiniLM-L12-v2")

def extract_keywords(tokens):
    if not isinstance(tokens, list) or len(tokens) == 0:
        return []
    text = " ".join(tokens)
    keywords = kw_model.extract_keywords(
        text,
        keyphrase_ngram_range=(1, 2),
        stop_words=None,
        top_n=5
    )
    return [kw[0] for kw in keywords]

suggest_df.loc[:, "onerilen_konular"] = suggest_df["lemmas"].apply(extract_keywords)
# Out:
# C:\Users\ismet bal\AppData\Local\Temp\ipykernel_25648\2840568943.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   suggest_df.loc[:, "onerilen_konular"] = suggest_df["lemmas"].apply(extract_keywords)

# %%
output_df = suggest_df[["lemmas", "onerilen_konular"]].copy()
output_df.to_csv("../data/lemmas_with_oneriler.csv", index=False, encoding="utf-8-sig")

# %%
import ast

df = pd.read_csv("../data/lemmas_with_oneriler.csv")
df["onerilen_konular"] = df["onerilen_konular"].apply(ast.literal_eval)
df["metin"] = df["onerilen_konular"].apply(lambda x: " ".join(x) if isinstance(x, list) else "")
df = df[df["metin"].str.strip().astype(bool)].copy()

# %% [markdown]
# __Elbow and Silhouette analysis were used to identify the optimal number of clusters for KMeans. The visualizations indicated that 6 clusters provided the best separation.__

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df["metin"])

# %%
from sklearn.cluster import KMeans

inertias = []
K_range = range(1, 15)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)

plt.plot(K_range, inertias, marker='o')
plt.xlabel("Küme Sayısı (k)")
plt.ylabel("Inertia")
plt.title("Elbow Yöntemi ile Küme Sayısı Seçimi")
plt.show()

# %%
from sklearn.metrics import silhouette_score

scores = []
K_range = range(2, 15)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X)
    score = silhouette_score(X, labels)
    scores.append(score)

plt.plot(K_range, scores, marker='o')
plt.xlabel("Küme Sayısı (k)")
plt.ylabel("Silhouette Skoru")
plt.title("Silhouette Yöntemi ile Küme Kalitesi")
plt.show()

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=6, random_state=42)
df["cluster"] = kmeans.fit_predict(X)

# %% [markdown]
# __This step involved analyzing the structure of each cluster to determine the specific themes of user suggestions and complaints.__

# %%
for i in range(6):
    print(f"\Cluster {i}")
    print(df[df["cluster"] == i]["onerilen_konular"].head(10).to_string(index=False))
# Out:
# \Cluster 0
# [şifre unut, kadar şifre, müşteri hizmet, gerçe...
# [şifre yenile, şifre, kod rağmen, değil müşteri...
# [şifre unut, unut şifre, şifre yenile, şifre, u...
# [şifre koy, uğraş şifre, koy şifre, şifre, türl...
# [tekrar defalarca, arkadaş şifre, şifre yenile,...
# [şifre yenile, çalış şifre, iste şifre, şifre, ...
# [şifre yenile, giriş şifre, şifre, güvenlik sor...
# [şifre unut, şifre iste, şifre, boyunca şifre, ...
# [şifre yenile, şifre, sürekli hata, hata, sürekli]
# [şifre kabul, şifre yen, hafta şifre, şifre, sa...
# \Cluster 1
# [kart işlem, aktar kart, kart bilgi, fatura yan...
# [yıldız kart, kimlik tanı, aktarım kimlik, kart...
# [kullandirtmayin kart, aktif kart, fakat kart, ...
# [kart iyi, kart başka, tavsiye kart, başka kart...
# [banka kart, kart yüklem, kart kalite, kaybet m...
# [hata kart, yükle kart, kimlik doğrula, gerekiy...
# [kredi kart, kart yükle, bugün kart, üstelik kr...
# [kart para, sanal kart, müşteri hizmet, ara müş...
# [kullan kart, inaktif kart, cevapla kart, kart ...
# [kart kır, kötü kart, kart hizmet, hal müşteri,...
# \Cluster 2
# [alışveriş hemen, tane alışveriş, alışveriş, pa...
# [sun hiçbir, hiçbir özellik, sun, hiçbir, özell...
# [sıfırla hediye, puan sıfırla, hediye otomatikm...
# [puan geri, puan git, böyle puan, git böyle, geri]
# [telefon sıfırla, aynı telefon, telefon aynı, t...
# [rağmen üye, üye değil, üye rağmen, üye, temsil...
# [wifi kapa, wifi, vahiy nternet, nternet vahiy,...
# [siz uğraşı, adam çalış, saat uğraş, çık kardeş...
# [mail, ilgili mail, mail hiçbir, ses gönder, mü...
# [google olay, google, store servis, tarih fatur...
# \Cluster 3
# [turkcell tesit, koy uzak, tesit para, numara t...
# [turkcell müşteri, gir bekle, yok turkcell, bit...
# [turkcell ayır, saat uğraş, yerine koy, kullan ...
# [şikayet turkcell, turkcell yönetim, hizmet ber...
# [calıstıgı calilmıyor, turkcell calıstıgı, cali...
# [kanser turkcell, çalış gerek, turkcell yakış, ...
# [google olay, turkcell, geçen google, artık tur...
# [şifre yenile, şifre, turkcell kullan, artık tu...
# [üye müşteri, müşteri hizmet, müşteri, turkcell...
# [kart bedel, kullan öde, turkcell hizmet, müşte...
# \Cluster 4
# [para lazım, içeri para, kal para, var yardımcı...
# [fatura öde, komisyon öde, para aktar, banka ka...
# [fatura araba, bitir fatura, yok gerek, fatura,...
# [ısrar banka, banka yıl, banka talimat, hesap b...
# [sanal kart, para yatır, kod para, daha güzel, ...
# [para gönder, yansı kullan, kart para, gönder, ...
# [abone fatura, para üst, böyle para, şey para, ...
# [hesap yansı, sonra hesap, hesap doğrula, hesap...
# [şey öğrenci, fatura sadece, fatura göster, gös...
# [güven kart, şahsi para, para yatır, hala öde, ...
# \Cluster 5
# [değil tavsiye, iyi değil, tavsiye, hiç iyi, de...
#                            [iyi değil, değil, iyi]
#  [iyi değil, eskiden iyi, eskiden, değil, iyi iyi]
#                            [iyi değil, değil, iyi]
#                            [iyi değil, değil, iyi]
#  [hiçbirşey iyi, iyi değil, hiçbirşey, değil, iyi]
#                              [iyi kötü, kötü, iyi]
# [müşteri hizmet, müşteri, hizmet, hizmet iyi, i...
# [para gönder, iyi değil, değil, gönder iyi, gön...
#                            [iyi değil, değil, iyi]

# %% [markdown]
# __Here, the most important keywords in each cluster were examined to identify the main areas of complaints and suggestions.__

# %%
from collections import Counter
import ast

for i in range(6):
    print(f"\Cluster {i}")
    kelimeler = []
    
    for val in df[df["cluster"] == i]["onerilen_konular"]:
        if isinstance(val, str):
            try:
                val = ast.literal_eval(val)
            except:
                continue
        if isinstance(val, list):
            kelimeler.extend(val)
    
    en_sik = Counter(kelimeler).most_common(6)
    print("Most Frequent Words:", [x[0] for x in en_sik])
# Out:
# \Cluster 0
# Most Frequent Words: ['şifre', 'şifre yenile', 'şifre unut', 'unut şifre', 'şifre gir', 'yeni şifre']
# \Cluster 1
# Most Frequent Words: ['sanal kart', 'kart kullan', 'banka kart', 'kredi kart', 'kart para', 'kart yüklem']
# \Cluster 2
# Most Frequent Words: ['gerek', 'yok', 'gerek yok', 'telefon', 'müşteri hizmet', 'keşke']
# \Cluster 3
# Most Frequent Words: ['turkcell', 'turkcell böyle', 'kullan turkcell', 'yok turkcell', 'müşteri', 'turkcell müşteri']
# \Cluster 4
# Most Frequent Words: ['fatura öde', 'banka', 'para gönder', 'banka hesap', 'fatura yansı', 'öde']
# \Cluster 5
# Most Frequent Words: ['iyi', 'iyi değil', 'değil', 'pek', 'iyi kötü', 'kötü']

# %%
from sklearn.decomposition import PCA

cluster_labels = {
    0: "Mail/Şifre Mail Sorunları",
    1: "Şifre Yenileme Problemleri",
    2: "Hesap/Banka Doğrulama",
    3: "Kart Problemleri",
    4: "Fatura/İşlem Ücretleri",
    5: "Kampanya/Puan/Özellik Şikayetleri"
}

df["cluster_label"] = df["cluster"].map(cluster_labels)
pca = PCA(n_components=2)
X_2d = pca.fit_transform(X.toarray())

plt.figure(figsize=(12, 8))
scatter = plt.scatter(X_2d[:, 0], X_2d[:, 1], c=df["cluster"], cmap="tab10", alpha=0.6)


for cluster_id in sorted(df["cluster"].unique()):
    indices = df["cluster"] == cluster_id
    x_mean = X_2d[indices, 0].mean()
    y_mean = X_2d[indices, 1].mean()
    plt.text(x_mean, y_mean, cluster_labels[cluster_id], fontsize=10, weight='bold', 
             bbox=dict(facecolor='white', alpha=0.8, edgecolor='gray'))

plt.title("Önerilen Konu Kümeleri (PCA)")
plt.xlabel("Bileşen 1")
plt.ylabel("Bileşen 2")
plt.colorbar(scatter, ticks=range(len(cluster_labels)))
plt.grid(True)
plt.show()

# %% [markdown]
# __We identified which keywords appeared most frequently in each cluster among the negative reviews.__

# %%
import seaborn as sns

rows = []
for i, row in df.iterrows():
    for kelime in row["metin"].split():
        rows.append({"cluster": row["cluster"], "kelime": kelime})

kelime_df = pd.DataFrame(rows)
sns.set(style="whitegrid")
plt.figure(figsize=(15, 10))

top_kelimeler = kelime_df["kelime"].value_counts().head(15).index

ax = sns.countplot(
    data=kelime_df[kelime_df["kelime"].isin(top_kelimeler)],
    y="kelime",
    hue="cluster",
    order=top_kelimeler,
    palette="Set2"
)
cluster_labels = {
    0: "Mail/Şifre Mail Sorunları",
    1: "Şifre Yenileme Problemleri",
    2: "Hesap/Banka Doğrulama",
    3: "Kart Problemleri",
    4: "Fatura/İşlem Ücretleri",
    5: "Kampanya/Puan/Özellik Şikayetleri"
}

for p in ax.patches:
    width = p.get_width()
    if width > 0:
        plt.text(width + 1,  
                 p.get_y() + p.get_height() / 2, 
                 int(width), ha="left", va="center", fontsize=9)

plt.title("Kümelere Göre En Sık 15 Kelime", fontsize=14)
plt.xlabel("Frekans", fontsize=12)
plt.ylabel("Kelime", fontsize=12)
plt.legend(title="Cluster", title_fontsize=11)
plt.tight_layout()
handles, labels = ax.get_legend_handles_labels()
new_labels = [cluster_labels[int(label)] for label in labels]
ax.legend(handles, new_labels, title="Kümeler", title_fontsize=11)
plt.show()

# %% [markdown]
# __Most frequent words in the negative reviews__

# %%
from collections import Counter

all_keywords = df["metin"].str.split().sum() 
common = Counter(all_keywords).most_common(20)

labels, counts = zip(*common)
plt.figure(figsize=(10, 5))
bars = plt.barh(labels, counts)
plt.gca().invert_yaxis()
plt.title("En Sık Geçen Anahtar Konular")
plt.xlabel("Frekans")
for bar in bars:
    width = bar.get_width()
    plt.text(width + 1, bar.get_y() + bar.get_height() / 2,
             str(int(width)), va='center', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# __FOR POZITIF DATAS__

# %% [markdown]
# __Applying the same analysis to the positive reviews as we did for the negative ones.__

# %%
import ast
df_cleaned = pd.read_csv("../data/sentiment_results.csv")
df_cleaned["lemmas"] = df_cleaned["lemmas"].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

positive_df = df_cleaned[df_cleaned["normalized_pred_label"] == "positive"].copy()
df_cleaned = positive_df.dropna(subset=["lemmas"])

# %%
suggest_df = df_cleaned[df_cleaned["normalized_pred_label"] == "positive"].copy()

# %% [markdown]
# __This model transforms sentence meanings into embeddings and extracts keywords by measuring semantic similarity.__

# %%
from keybert import KeyBERT

kw_model = KeyBERT(model="paraphrase-multilingual-MiniLM-L12-v2")

def extract_keywords(tokens):
    if not isinstance(tokens, list) or len(tokens) == 0:
        return []
    text = " ".join(tokens)
    keywords = kw_model.extract_keywords(
        text,
        keyphrase_ngram_range=(1, 2),
        stop_words=None,
        top_n=5
    )
    return [kw[0] for kw in keywords]

suggest_df.loc[:, "positif_oneriler"] = suggest_df["lemmas"].apply(extract_keywords)

# %%
output_df = suggest_df[["lemmas", "positif_oneriler"]].copy()
output_df.to_csv("../data/lemmas_suggest_positive.csv", index=False, encoding="utf-8-sig")

# %%
import ast

df = pd.read_csv("../data/lemmas_suggest_positive.csv")

df["positif_oneriler"] = df["positif_oneriler"].apply(ast.literal_eval)

df["metin"] = df["positif_oneriler"].apply(
    lambda x: " ".join(x) if isinstance(x, list) else ""
)

df = df[df["metin"].str.strip().astype(bool)].copy()

# %% [markdown]
# __We selected 3 clusters based on Elbow and Silhouette methods, as well as several experimental trials.__

# %%
from sklearn.cluster import KMeans

inertias = []
K_range = range(1, 15)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)

plt.plot(K_range, inertias, marker='o')
plt.xlabel("Küme Sayısı (k)")
plt.ylabel("Inertia")
plt.title("Elbow Yöntemi ile Küme Sayısı Seçimi")
plt.show()

# %%
from sklearn.metrics import silhouette_score

scores = []
K_range = range(2, 15)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X)
    score = silhouette_score(X, labels)
    scores.append(score)

plt.plot(K_range, scores, marker='o')
plt.xlabel("Küme Sayısı (k)")
plt.ylabel("Silhouette Skoru")
plt.title("Silhouette Yöntemi ile Küme Kalitesi")
plt.show()

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df["metin"])

kmeans = KMeans(n_clusters=4, random_state=42)
df["cluster"] = kmeans.fit_predict(X)

# %%
for i in range(4):
    print(f"\nKÜME {i}")
    print(df[df["cluster"] == i]["positif_oneriler"].head(5).to_string(index=False))
# Out:
# KÜME 0
#                            [sakin gir, sakin, gir]
# [ait yüz, kimlik fotoğraf, yüz, yüz doğrula, fo...
#                                              [iyi]
# [güvenlik anahtar, anahtar daha, çalışıyum güve...
# [mükemmel hediye, hediye hoş, hediye, allah siz...
#
# KÜME 1
# [harika]
# [harika]
# [harika]
# [harika]
# [harika]
#
# KÜME 2
#                  [güzel teşekkür, teşekkür, güzel]
# [iade teşekkür, teşekkür, sonunda iade, sonunda...
# [hız teşekkür, işlem hız, iyi işlem, hız, teşek...
# [teşekkür paycellcüzdanödemekart, anlayış teşek...
# [kart güzel, trol kart, güzel teşekkür, teşekkü...
#
# KÜME 3
# [güzel]
# [güzel]
# [güzel]
# [güzel]
# [güzel]

# %% [markdown]
# __Here, words were clustered into 3 groups based on their semantic similarity, and the resulting distributions were visualized.__

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_2d = pca.fit_transform(X.toarray())

plt.figure(figsize=(10, 6))
scatter = plt.scatter(X_2d[:, 0], X_2d[:, 1], c=df["cluster"], cmap="tab10")
plt.title("KMeans ile Önerilen Konu Kümeleme (PCA)")
plt.xlabel("Bileşen 1")
plt.ylabel("Bileşen 2")
plt.colorbar(scatter, ticks=range(4))
plt.grid(True)
plt.show()

# %% [markdown]
# __The most frequently used positive word was identified.__

# %%
from collections import Counter

all_keywords = df["metin"].str.split().sum() 
common = Counter(all_keywords).most_common(20)

labels, counts = zip(*common)
plt.figure(figsize=(10, 5))
plt.barh(labels, counts)
plt.gca().invert_yaxis()
plt.title("En Sık Geçen Anahtar Konular")
plt.xlabel("Frekans")
plt.show()

# %% [markdown]
# __A visual representation of the distribution of the most frequent words across different clusters.__

# %%
import seaborn as sns

rows = []
for i, row in df.iterrows():
    for kelime in row["metin"].split():
        rows.append({"cluster": row["cluster"], "kelime": kelime})

kelime_df = pd.DataFrame(rows)
plt.figure(figsize=(12, 6))
sns.countplot(data=kelime_df, y="kelime", order=kelime_df["kelime"].value_counts().head(15).index, hue="cluster")
plt.title("Kümelere Göre En Sık Kelimeler")
plt.show()
