# %% [markdown]
# __This study investigates user feedback on the Paycell mobile application by analyzing Google Play Store reviews. The analysis focuses on identifying common complaints, user suggestions, and overall sentiment distribution.__

# %%
from google_play_scraper import Sort, reviews
import pandas as pd
import time

# %% [markdown]
# **Using a custom Play Store scraper, we extracted 68,980 user reviews from the Paycell application.**

# %%
results, _ = reviews ('com.turkcell.paycell',
                      lang='tr',
                      country='tr',
                      sort=Sort.NEWEST,
                      count=68980
                     )

# %%
print(len(results))
# Out:
# 68980

# %%
results[0]
# Out:
# {'reviewId': '9ca9de93-73c9-4f23-bcaa-09d8cd1d8ece',
#  'userName': 'Google kullanıcısı',
#  'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#  'content': 'paycell açılmıyor',
#  'score': 1,
#  'thumbsUpCount': 0,
#  'reviewCreatedVersion': '9.6.0',
#  'at': datetime.datetime(2025, 11, 24, 16, 8, 27),
#  'replyContent': None,
#  'repliedAt': None,
#  'appVersion': '9.6.0'}

# %%
df = pd.DataFrame(results)
df = df[['content', 'score', 'at']]
df.columns = ['Yorum', 'Puan', 'Tarih']

# %%
df
# Out:
#                                                    Yorum  Puan  \
# 0                                      paycell açılmıyor     1
# 1          beş para etmez bir uygulama, tam turkcell işi     1
# 2      ilk başta mağazadan kartımı aldım ve orada işl...     1
# 3                       çok iyi halen daha kullanıyorum.     5
# 4               uygulamaya geç giriyor bazen de girmiyor     1
# ...                                                  ...   ...
# 68975                                          Çok güzel     5
# 68976  Mobil ödeme bakiye ve islem tarihcesi goruntul...     5
# 68977                                       Beklemedeyiz     4
# 68978                                        Fine hit :)     5
# 68979                 Gayet başarılı ve kullanıcı dostu.     5
#
#                     Tarih
# 0     2025-11-24 16:08:27
# 1     2025-11-24 15:55:07
# 2     2025-11-24 15:37:12
# 3     2025-11-24 15:11:45
# 4     2025-11-24 15:07:40
# ...                   ...
# ...

# %%
df.to_csv("../data/paycell_reviews_play_store.csv", index=False)
